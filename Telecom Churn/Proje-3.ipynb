# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cell2celltrain.csv')
data = pd.read_csv('cell2cellholdout.csv')

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %%
sns.catplot(x='CreditRating',y='MonthlyMinutes',hue='Churn',kind='swarm',data=df)

# %%
for i in range(1,len(df.select_dtypes(exclude=['int64','float64']).columns)) :
    print(df[df.select_dtypes(exclude=['int64','float64']).columns[i]].value_counts())
    print('-------------------------------')
    i += 1
# Out:
# NYCBRO917    1684
# HOUHOU281    1510
# DALDAL214    1498
# NYCMAN917    1182
# APCFCH703     783
#              ...
# INDCRA765       1
# VAHWAY540       1
# NCRHGP336       1
# SFRRCM510       1
# NCRLUM910       1
# Name: ServiceArea, Length: 747, dtype: int64
# -------------------------------
# No     38679
# Yes    12368
# Name: ChildrenInHH, dtype: int64
# -------------------------------
# No     43956
# Yes     7091
# Name: HandsetRefurbished, dtype: int64
# -------------------------------
# Yes    46046
# No      5001
# Name: HandsetWebCapable, dtype: int64
# -------------------------------
# No     41524
# Yes     9523
# Name: TruckOwner, dtype: int64
# -------------------------------
# No     46894
# Yes     4153
# Name: RVOwner, dtype: int64
# -------------------------------
# Known      33987
# Unknown    17060
# Name: Homeownership, dtype: int64
# -------------------------------
# No     32596
# Yes    18451
# Name: BuysViaMailOrder, dtype: int64
# ...

# %%
for i in range(1,len(df.select_dtypes(exclude=['int64','float64']).columns)) :
    print(df.select_dtypes(exclude=['int64','float64']).columns[i],' : ',df[df.select_dtypes(exclude=['int64','float64']).columns[i]].nunique())
    print('-------------------------------')
    i += 1
# Out:
# ServiceArea  :  747
# -------------------------------
# ChildrenInHH  :  2
# -------------------------------
# HandsetRefurbished  :  2
# -------------------------------
# HandsetWebCapable  :  2
# -------------------------------
# TruckOwner  :  2
# -------------------------------
# RVOwner  :  2
# -------------------------------
# Homeownership  :  2
# -------------------------------
# BuysViaMailOrder  :  2
# -------------------------------
# RespondsToMailOffers  :  2
# -------------------------------
# OptOutMailings  :  2
# -------------------------------
# NonUSTravel  :  2
# -------------------------------
# OwnsComputer  :  2
# -------------------------------
# HasCreditCard  :  2
# -------------------------------
# NewCellphoneUser  :  2
# -------------------------------
# NotNewCellphoneUser  :  2
# -------------------------------
# OwnsMotorcycle  :  2
# -------------------------------
# HandsetPrice  :  16
# -------------------------------
# ...

# %%
for i in range(1,len(df.select_dtypes(include=['int64','float64']).columns)) :
    print(df.select_dtypes(include=['int64','float64']).columns[i],' : ',df[df.select_dtypes(include=['int64','float64']).columns[i]].nunique())
    print('-------------------------------')
    i += 1
# Out:
# MonthlyRevenue  :  12665
# -------------------------------
# MonthlyMinutes  :  2719
# -------------------------------
# TotalRecurringCharge  :  214
# -------------------------------
# DirectorAssistedCalls  :  146
# -------------------------------
# OverageMinutes  :  746
# -------------------------------
# RoamingCalls  :  530
# -------------------------------
# PercChangeMinutes  :  2262
# -------------------------------
# PercChangeRevenues  :  2899
# -------------------------------
# DroppedCalls  :  285
# -------------------------------
# BlockedCalls  :  373
# -------------------------------
# UnansweredCalls  :  840
# -------------------------------
# CustomerCareCalls  :  185
# -------------------------------
# ThreewayCalls  :  78
# -------------------------------
# ReceivedCalls  :  6121
# -------------------------------
# OutboundCalls  :  787
# -------------------------------
# InboundCalls  :  472
# -------------------------------
# PeakCallsInOut  :  1839
# ...

# %%
for i in range(0,len(df.columns)) :
    print(df.columns[i],' :',df[df.columns[i]].nunique())
    print('-------------------------------')
    i += 1
# Out:
# CustomerID  : 51047
# -------------------------------
# Churn  : 2
# -------------------------------
# MonthlyRevenue  : 12665
# -------------------------------
# MonthlyMinutes  : 2719
# -------------------------------
# TotalRecurringCharge  : 214
# -------------------------------
# DirectorAssistedCalls  : 146
# -------------------------------
# OverageMinutes  : 746
# -------------------------------
# RoamingCalls  : 530
# -------------------------------
# PercChangeMinutes  : 2262
# -------------------------------
# PercChangeRevenues  : 2899
# -------------------------------
# DroppedCalls  : 285
# -------------------------------
# BlockedCalls  : 373
# -------------------------------
# UnansweredCalls  : 840
# -------------------------------
# CustomerCareCalls  : 185
# -------------------------------
# ThreewayCalls  : 78
# -------------------------------
# ReceivedCalls  : 6121
# -------------------------------
# OutboundCalls  : 787
# -------------------------------
# ...

# %%
df.select_dtypes(['int64','float64']).describe()
# Out:
#          CustomerID  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# count  5.104700e+04    50891.000000    50891.000000          50891.000000
# mean   3.201957e+06       58.834492      525.653416             46.830088
# std    1.169056e+05       44.507336      529.871063             23.848871
# min    3.000002e+06       -6.170000        0.000000            -11.000000
# 25%    3.100632e+06       33.610000      158.000000             30.000000
# 50%    3.201534e+06       48.460000      366.000000             45.000000
# 75%    3.305376e+06       71.065000      723.000000             60.000000
# max    3.399994e+06     1223.380000     7359.000000            400.000000
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# count           50891.000000    50891.000000  50891.000000       50680.000000
# mean                0.895229       40.027785      1.236244         -11.547908
# ...

# %%
df.Churn.value_counts().plot.bar()
print(df.Churn.value_counts())
# Out:
# No     36336
# Yes    14711
# Name: Churn, dtype: int64

# %%
df.groupby(['CreditRating']).MonthlyMinutes.sum()
# Out:
# CreditRating
# 1-Highest    3399580.0
# 2-High       8284435.0
# 3-Good       4806603.0
# 4-Medium     3398474.0
# 5-Low        4748827.0
# 6-VeryLow     663572.0
# 7-Lowest     1449537.0
# Name: MonthlyMinutes, dtype: float64

# %%
missing = list()
for x in df.select_dtypes(['float64','int64']).columns:
    if df[x].isnull().sum() != 0:
        print(x, df[x].isnull().sum())
        missing.append(x)
# Out:
# MonthlyRevenue 156
# MonthlyMinutes 156
# TotalRecurringCharge 156
# DirectorAssistedCalls 156
# OverageMinutes 156
# RoamingCalls 156
# PercChangeMinutes 367
# PercChangeRevenues 367
# Handsets 1
# HandsetModels 1
# CurrentEquipmentDays 1
# AgeHH1 909
# AgeHH2 909

# %%
a=[]
b=[]
c=[]
d=[]

for x in range(0,len(missing)):
    if df[missing[x]].isnull().sum() == 156:
        a.append(missing[x])
        print(missing[x],df[missing[x]].isnull().sum())
    elif df[missing[x]].isnull().sum() == 367:
        b.append(missing[x])
        print(missing[x],df[missing[x]].isnull().sum())
    elif df[missing[x]].isnull().sum() == 1:
        c.append(missing[x])
        print(missing[x],df[missing[x]].isnull().sum())
    elif df[missing[x]].isnull().sum() == 909:
        d.append(missing[x])
        print(missing[x],df[missing[x]].isnull().sum())
# Out:
# MonthlyRevenue 156
# MonthlyMinutes 156
# TotalRecurringCharge 156
# DirectorAssistedCalls 156
# OverageMinutes 156
# RoamingCalls 156
# PercChangeMinutes 367
# PercChangeRevenues 367
# Handsets 1
# HandsetModels 1
# CurrentEquipmentDays 1
# AgeHH1 909
# AgeHH2 909

# %%
for i in range(0,len(c)) :
    df[c[i]]=df[c[i]].fillna(df[c[i]].mean())
    df[c[i]] = df[c[i]].astype('int64')
    i += 1

# %%
for i in range(0,len(d)) :
    not_zero = df[df[d[i]] != 0.0]
    mean = not_zero[d[i]].mean()
    std = not_zero[d[i]].std()
    is_null = df[d[i]].isnull().sum()
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    age_slice = df[d[i]].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df[d[i]] = age_slice
    df[d[i]] = df[d[i]].astype('int64')
    i += 1

# %%
for i in range(0,len(b)) :
    mean = df[b[i]].mean()
    std = df[b[i]].std()
    is_null = df[b[i]].isnull().sum()
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    age_slice = df[b[i]].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df[b[i]] = age_slice
    df[b[i]] = df[b[i]].astype('int64')
    i += 1

# %%
d
# Out:
# ['AgeHH1', 'AgeHH2']

# %%
a1 =[]
for i in range(0,len(a)) : 
    if i > 3 :
        a1.append(a[i])

# %%
for i in range(2) :
    a.pop(4)

# %%
for i in range(0,len(a)) :
    mean = df[a[i]].mean()
    std = df[a[i]].std()
    is_null = df[a[i]].isnull().sum()
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    age_slice = df[a[i]].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df[a[i]] = age_slice
    df[a[i]] = df[a[i]].astype('int64')
    i += 1

# %%
for i in range(0,len(a1)) :
    not_zero = df[df[a1[i]] != 0.0]
    mean = not_zero[a1[i]].mean()
    std = not_zero[a1[i]].std()
    is_null = df[a1[i]].isnull().sum()
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    age_slice = df[a1[i]].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df[a1[i]] = age_slice
    df[a1[i]] = df[a1[i]].astype('int64')
    i += 1

# %%
df.select_dtypes(exclude=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   MonthlyRevenue             51047 non-null  int64
#  2   MonthlyMinutes             51047 non-null  int64
#  3   TotalRecurringCharge       51047 non-null  int64
#  4   DirectorAssistedCalls      51047 non-null  int64
#  5   OverageMinutes             51047 non-null  int64
#  6   RoamingCalls               51047 non-null  int64
#  7   PercChangeMinutes          51047 non-null  int64
#  8   PercChangeRevenues         51047 non-null  int64
#  9   DroppedCalls               51047 non-null  float64
#  10  BlockedCalls               51047 non-null  float64
#  11  UnansweredCalls            51047 non-null  float64
#  12  CustomerCareCalls          51047 non-null  float64
# ...

# %%
df.select_dtypes(['object']).isnull().sum()
# Out:
# Churn                       0
# ServiceArea                24
# ChildrenInHH                0
# HandsetRefurbished          0
# HandsetWebCapable           0
# TruckOwner                  0
# RVOwner                     0
# Homeownership               0
# BuysViaMailOrder            0
# RespondsToMailOffers        0
# OptOutMailings              0
# NonUSTravel                 0
# OwnsComputer                0
# HasCreditCard               0
# NewCellphoneUser            0
# NotNewCellphoneUser         0
# OwnsMotorcycle              0
# HandsetPrice                0
# MadeCallToRetentionTeam     0
# CreditRating                0
# PrizmCode                   0
# Occupation                  0
# MaritalStatus               0
# dtype: int64

# %%
df.ServiceArea.describe()
# Out:
# count         51023
# unique          747
# top       NYCBRO917
# freq           1684
# Name: ServiceArea, dtype: object

# %%
qq='NYCBRO917'
df=df.fillna(qq)

# %%
df.isnull().sum()
# Out:
# CustomerID                   0
# Churn                        0
# MonthlyRevenue               0
# MonthlyMinutes               0
# TotalRecurringCharge         0
# DirectorAssistedCalls        0
# OverageMinutes               0
# RoamingCalls                 0
# PercChangeMinutes            0
# PercChangeRevenues           0
# DroppedCalls                 0
# BlockedCalls                 0
# UnansweredCalls              0
# CustomerCareCalls            0
# ThreewayCalls                0
# ReceivedCalls                0
# OutboundCalls                0
# InboundCalls                 0
# PeakCallsInOut               0
# OffPeakCallsInOut            0
# DroppedBlockedCalls          0
# CallForwardingCalls          0
# CallWaitingCalls             0
# MonthsInService              0
# UniqueSubs                   0
# ActiveSubs                   0
# ServiceArea                  0
# Handsets                     0
# HandsetModels                0
# CurrentEquipmentDays         0
# ...

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes              24             219                    22
# 1     3000010   Yes              16              10                    17
# 2     3000014    No              38               8                    38
# 3     3000022    No              82            1312                    75
# 4     3000026   Yes              17               0                    17
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                      0               0             0               -157
# 1                      0               0             0                 -4
# 2                      0               0             0                 -2
# 3                      1               0             0                157
# 4                      0               0             0                  0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
for i in range(0,len(df.select_dtypes(include=['object']).columns)) :
    print(df.select_dtypes(include=['object']).columns[i],'\n',df[df.select_dtypes(include=['object']).columns[i]].value_counts())
    print('--------------------------------------------------')
    i += 1
# Out:
# Churn
#  No     36336
# Yes    14711
# Name: Churn, dtype: int64
# --------------------------------------------------
# ServiceArea
#  NYCBRO917    1708
# HOUHOU281    1510
# DALDAL214    1498
# NYCMAN917    1182
# APCFCH703     783
#              ...
# INDCRA765       1
# VAHWAY540       1
# NCRHGP336       1
# SFRRCM510       1
# NCRLUM910       1
# Name: ServiceArea, Length: 747, dtype: int64
# --------------------------------------------------
# ChildrenInHH
#  No     38679
# Yes    12368
# Name: ChildrenInHH, dtype: int64
# --------------------------------------------------
# HandsetRefurbished
#  No     43956
# Yes     7091
# Name: HandsetRefurbished, dtype: int64
# --------------------------------------------------
# HandsetWebCapable
#  Yes    46046
# No      5001
# Name: HandsetWebCapable, dtype: int64
# --------------------------------------------------
# TruckOwner
#  No     41524
# Yes     9523
# Name: TruckOwner, dtype: int64
# ...

# %%
for i in range(0,len(df.select_dtypes(include=['object']).columns)) :
    print(df.select_dtypes(include=['object']).columns[i],df[df.select_dtypes(include=['object']).columns[i]].nunique())
    print('-------------------------------')
    i += 1
# Out:
# Churn 2
# -------------------------------
# ServiceArea 747
# -------------------------------
# ChildrenInHH 2
# -------------------------------
# HandsetRefurbished 2
# -------------------------------
# HandsetWebCapable 2
# -------------------------------
# TruckOwner 2
# -------------------------------
# RVOwner 2
# -------------------------------
# Homeownership 2
# -------------------------------
# BuysViaMailOrder 2
# -------------------------------
# RespondsToMailOffers 2
# -------------------------------
# OptOutMailings 2
# -------------------------------
# NonUSTravel 2
# -------------------------------
# OwnsComputer 2
# -------------------------------
# HasCreditCard 2
# -------------------------------
# NewCellphoneUser 2
# -------------------------------
# NotNewCellphoneUser 2
# -------------------------------
# OwnsMotorcycle 2
# -------------------------------
# HandsetPrice 16
# -------------------------------
# MadeCallToRetentionTeam 2
# ...

# %%
value2 = []
for i in range(0,len(df.select_dtypes(['object']).columns)) :
    x=df[df.select_dtypes(['object']).columns[i]].nunique()
    if x == 2 :
        print(df.select_dtypes(['object']).columns[i],' : ',df[df.select_dtypes(['object']).columns[i]].nunique())
        value2.append(df.select_dtypes(['object']).columns[i])
    i += 1
# Out:
# Churn  :  2
# ChildrenInHH  :  2
# HandsetRefurbished  :  2
# HandsetWebCapable  :  2
# TruckOwner  :  2
# RVOwner  :  2
# Homeownership  :  2
# BuysViaMailOrder  :  2
# RespondsToMailOffers  :  2
# OptOutMailings  :  2
# NonUSTravel  :  2
# OwnsComputer  :  2
# HasCreditCard  :  2
# NewCellphoneUser  :  2
# NotNewCellphoneUser  :  2
# OwnsMotorcycle  :  2
# MadeCallToRetentionTeam  :  2

# %%
df2=df.loc[:,value2]
df2=df2.drop('Churn',axis=1)
df2.head()
# Out:
#   ChildrenInHH HandsetRefurbished HandsetWebCapable TruckOwner RVOwner  \
# 0           No                 No               Yes         No      No
# 1          Yes                 No                No         No      No
# 2          Yes                 No                No         No      No
# 3           No                 No               Yes         No      No
# 4           No                 No                No         No      No
#
#   Homeownership BuysViaMailOrder RespondsToMailOffers OptOutMailings  \
# 0         Known              Yes                  Yes             No
# 1         Known              Yes                  Yes             No
# 2       Unknown               No                   No             No
# 3         Known              Yes                  Yes             No
# 4         Known              Yes                  Yes             No
#
#   NonUSTravel OwnsComputer HasCreditCard NewCellphoneUser NotNewCellphoneUser  \
# ...

# %%
for i in range(0,len(df2.columns)) : 
    df2[df2.columns[i]]=df2[df2.columns[i]].replace(list(df2[df2.columns[i]].unique()),np.arange(2))
    df2[df2.columns[i]] = df2[df2.columns[i]].astype('int64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ChildrenInHH             51047 non-null  int64
#  1   HandsetRefurbished       51047 non-null  int64
#  2   HandsetWebCapable        51047 non-null  int64
#  3   TruckOwner               51047 non-null  int64
#  4   RVOwner                  51047 non-null  int64
#  5   Homeownership            51047 non-null  int64
#  6   BuysViaMailOrder         51047 non-null  int64
#  7   RespondsToMailOffers     51047 non-null  int64
#  8   OptOutMailings           51047 non-null  int64
#  9   NonUSTravel              51047 non-null  int64
#  10  OwnsComputer             51047 non-null  int64
#  11  HasCreditCard            51047 non-null  int64
#  12  NewCellphoneUser         51047 non-null  int64
#  13  NotNewCellphoneUser      51047 non-null  int64
# ...

# %%
for i in range(0,len(df.select_dtypes(include=['object']).columns)) :
    print(df.select_dtypes(include=['object']).columns[i],df[df.select_dtypes(include=['object']).columns[i]].nunique())
    print('-------------------------------')
    i += 1
# Out:
# Churn 2
# -------------------------------
# ServiceArea 747
# -------------------------------
# ChildrenInHH 2
# -------------------------------
# HandsetRefurbished 2
# -------------------------------
# HandsetWebCapable 2
# -------------------------------
# TruckOwner 2
# -------------------------------
# RVOwner 2
# -------------------------------
# Homeownership 2
# -------------------------------
# BuysViaMailOrder 2
# -------------------------------
# RespondsToMailOffers 2
# -------------------------------
# OptOutMailings 2
# -------------------------------
# NonUSTravel 2
# -------------------------------
# OwnsComputer 2
# -------------------------------
# HasCreditCard 2
# -------------------------------
# NewCellphoneUser 2
# -------------------------------
# NotNewCellphoneUser 2
# -------------------------------
# OwnsMotorcycle 2
# -------------------------------
# HandsetPrice 16
# -------------------------------
# MadeCallToRetentionTeam 2
# ...

# %%
df['MaritalStatus']=df['MaritalStatus'].replace(list(df['MaritalStatus'].unique()),np.arange(3))
df['MaritalStatus'] = df['MaritalStatus'].astype('int64')

# %%
df['PrizmCode']=df['PrizmCode'].replace(list(df['PrizmCode'].unique()),np.arange(4))
df['PrizmCode'] = df['PrizmCode'].astype('int64')
df['CreditRating']=df['CreditRating'].replace(list(df['CreditRating'].unique()),np.arange(7))
df['CreditRating'] = df['CreditRating'].astype('int64')
df['Occupation']=df['Occupation'].replace(list(df['Occupation'].unique()),np.arange(8))
df['Occupation'] = df['Occupation'].astype('int64')

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes              24             219                    22
# 1     3000010   Yes              16              10                    17
# 2     3000014    No              38               8                    38
# 3     3000022    No              82            1312                    75
# 4     3000026   Yes              17               0                    17
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                      0               0             0               -157
# 1                      0               0             0                 -4
# 2                      0               0             0                 -2
# 3                      1               0             0                157
# 4                      0               0             0                  0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
train_df = df.copy()

# %%
train_df=train_df.select_dtypes(exclude = ['object'])

# %%
train_df.head()
# Out:
#    CustomerID  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002              24             219                    22
# 1     3000010              16              10                    17
# 2     3000014              38               8                    38
# 3     3000022              82            1312                    75
# 4     3000026              17               0                    17
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                      0               0             0               -157
# 1                      0               0             0                 -4
# 2                      0               0             0                 -2
# 3                      1               0             0                157
# 4                      0               0             0                  0
#
#    PercChangeRevenues  DroppedCalls  ...  AgeHH2  RetentionCalls  \
# ...

# %%
train_df['HandsetPrice'] = df.HandsetPrice
train_df['ServiceArea'] = df.ServiceArea

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   MonthlyRevenue             51047 non-null  int64
#  2   MonthlyMinutes             51047 non-null  int64
#  3   TotalRecurringCharge       51047 non-null  int64
#  4   DirectorAssistedCalls      51047 non-null  int64
#  5   OverageMinutes             51047 non-null  int64
#  6   RoamingCalls               51047 non-null  int64
#  7   PercChangeMinutes          51047 non-null  int64
#  8   PercChangeRevenues         51047 non-null  int64
#  9   DroppedCalls               51047 non-null  float64
#  10  BlockedCalls               51047 non-null  float64
#  11  UnansweredCalls            51047 non-null  float64
#  12  CustomerCareCalls          51047 non-null  float64
# ...

# %%
train_df = pd.concat([train_df,df2],axis=1)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   MonthlyRevenue             51047 non-null  int64
#  2   MonthlyMinutes             51047 non-null  int64
#  3   TotalRecurringCharge       51047 non-null  int64
#  4   DirectorAssistedCalls      51047 non-null  int64
#  5   OverageMinutes             51047 non-null  int64
#  6   RoamingCalls               51047 non-null  int64
#  7   PercChangeMinutes          51047 non-null  int64
#  8   PercChangeRevenues         51047 non-null  int64
#  9   DroppedCalls               51047 non-null  float64
#  10  BlockedCalls               51047 non-null  float64
#  11  UnansweredCalls            51047 non-null  float64
#  12  CustomerCareCalls          51047 non-null  float64
# ...

# %%
train_df.HandsetPrice.value_counts()
# Out:
# Unknown    28982
# 30          7328
# 150         4115
# 130         2105
# 80          1960
# 10          1928
# 60          1776
# 200         1266
# 100         1235
# 40           249
# 400           46
# 250           20
# 300           13
# 180           10
# 500            8
# 240            6
# Name: HandsetPrice, dtype: int64

# %%
train_df['HandsetPrice'] = train_df.HandsetPrice.replace('Unknown',0)

# %%
train_df['HandsetPrice'] = pd.to_numeric(train_df['HandsetPrice'], downcast="float")
train_df['HandsetPrice'] = train_df.HandsetPrice.astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[ dataset['HandsetPrice'] < 10, 'HandsetPrice'] = 0
    dataset.loc[(dataset['HandsetPrice'] >= 10) & (dataset['HandsetPrice'] <= 40), 'HandsetPrice'] = 1
    dataset.loc[(dataset['HandsetPrice'] >= 60) & (dataset['HandsetPrice'] <= 100), 'HandsetPrice'] = 2
    dataset.loc[(dataset['HandsetPrice'] >= 130) & (dataset['HandsetPrice'] <= 180), 'HandsetPrice'] = 3
    dataset.loc[(dataset['HandsetPrice'] >= 200) & (dataset['HandsetPrice'] <= 250), 'HandsetPrice'] = 4
    dataset.loc[(dataset['HandsetPrice'] >= 300) & (dataset['HandsetPrice'] <= 500), 'HandsetPrice'] = 5

# %%
train_df.describe()
# Out:
#          CustomerID  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# count  5.104700e+04    51047.000000    51047.000000          51047.000000
# mean   3.201957e+06       58.334868      525.742531             46.823574
# std    1.169056e+05       44.460615      529.332895             23.823071
# min    3.000002e+06       -6.000000       -1.000000            -11.000000
# 25%    3.100632e+06       33.000000      158.000000             30.000000
# 50%    3.201534e+06       48.000000      367.000000             45.000000
# 75%    3.305376e+06       71.000000      724.000000             60.000000
# max    3.399994e+06     1223.000000     7359.000000            400.000000
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# count           51047.000000    51047.000000  51047.000000       51047.000000
# mean                0.628382       40.129410      1.119341         -11.562952
# ...

# %%
train_df.ServiceArea.unique()
# Out:
# array(['SEAPOR503', 'PITHOM412', 'MILMIL414', 'OKCTUL918', 'OKCOKC405',
#        'SANMCA210', 'SLCSLC801', 'LOULOU502', 'KCYKCK913', 'KCYNEW316',
#        'KCYKCM816', 'DENDEN303', 'PHICTR610', 'OKCLRK501', 'OMADES515',
#        'SANAUS512', 'KCYWIC316', 'INDIND317', 'SLCPRO801', 'OMALNC402',
#        'NSHNSH615', 'OMAOMA402', 'PHXTUC520', 'DALDAL214', 'DALDTN940',
#        'DALFTW817', 'SANSAN210', 'NYCMAN917', 'NOLKEN504', 'MINMIN612',
#        'NNYROC716', 'PHIARD610', 'NYCQUE917', 'DENBOU303', 'BOSBOS617',
#        'PHXPHX602', 'NNYBUF716', 'DETTOL419', 'NNYSYR315', 'STLSTL314',
#        'PHIPHI215', 'SEABLV425', 'MIAMIA305', 'PHICHC215', 'SEASEA206',
#        'BIRBIR205', 'MIADFD954', 'LOUNAL812', 'MIADEL561', 'MIAFTL954',
#        'SEASPO509', 'SEATAC253', 'SFRSAC916', 'MIANDA305', 'MINSTP612',
#        'MIAHWD954', 'NYCBRO917', 'PHIJEN215', 'OMACDR319', 'MIAWPB561',
#        'SEAOLY360', 'PITBUT412', 'SEAEVE425', 'PHIMER609', 'SEACDA208',
# ...

# %%
import re
data = [train_df]
for dataset in data:
    dataset['ServiceArea'] = dataset['ServiceArea'].map(lambda x: re.compile("(^[\s\S]{0,3})").search(x).group())

# %%
train_df.head()
# Out:
#    CustomerID  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002              24             219                    22
# 1     3000010              16              10                    17
# 2     3000014              38               8                    38
# 3     3000022              82            1312                    75
# 4     3000026              17               0                    17
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                      0               0             0               -157
# 1                      0               0             0                 -4
# 2                      0               0             0                 -2
# 3                      1               0             0                157
# 4                      0               0             0                  0
#
#    PercChangeRevenues  DroppedCalls  ...  BuysViaMailOrder  \
# ...

# %%
less20 = []
less500 = []
less1000 = []
less2000 = []
more2000 = []
for i in range(0,len(train_df.select_dtypes(exclude=['object']).columns)) :
    print(train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique())
    print('-------------------------------')
    if train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique() <= 20 and train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()>10:
        less20.append([train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()])
    if train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique() <= 500 and train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()>20:
        less500.append([train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()])
    if train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique() <= 1000 and train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()>500:
        less1000.append([train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()])
    if train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique() <= 2000 and train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()>1000:
        less2000.append([train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()])
    if train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique() >2000 :
        more2000.append([train_df.select_dtypes(exclude=['object']).columns[i],train_df[train_df.select_dtypes(exclude=['object']).columns[i]].nunique()])
    
    
    i += 1
# Out:
# CustomerID 51047
# -------------------------------
# MonthlyRevenue 422
# -------------------------------
# MonthlyMinutes 2720
# -------------------------------
# TotalRecurringCharge 214
# -------------------------------
# DirectorAssistedCalls 47
# -------------------------------
# OverageMinutes 767
# -------------------------------
# RoamingCalls 139
# -------------------------------
# PercChangeMinutes 2262
# -------------------------------
# PercChangeRevenues 540
# -------------------------------
# DroppedCalls 285
# -------------------------------
# BlockedCalls 373
# -------------------------------
# UnansweredCalls 840
# -------------------------------
# CustomerCareCalls 185
# -------------------------------
# ThreewayCalls 78
# -------------------------------
# ReceivedCalls 6121
# -------------------------------
# OutboundCalls 787
# -------------------------------
# InboundCalls 472
# -------------------------------
# PeakCallsInOut 1839
# ...

# %%
print('less20 {}\nless500 {} \nless1000 {} \nless2000 {} \nmore2000 {} \n'.format(len(less20),len(less500),len(less1000),len(less2000),len(more2000)))
# Out:
# less20 5
# less500 16
# less1000 4
# less2000 3
# more2000 4

# %%
less2000
# Out:
# [['PeakCallsInOut', 1839],
#  ['OffPeakCallsInOut', 1669],
#  ['CurrentEquipmentDays', 1438]]

# %%
train_df.CurrentEquipmentDays.value_counts()
# Out:
# 202     159
# 313     156
# 212     149
# 199     147
# 308     147
#        ...
# 1368      1
# 1208      1
# 1412      1
# 1096      1
# 1227      1
# Name: CurrentEquipmentDays, Length: 1438, dtype: int64

# %%
data = [train_df]
for dataset in data:
    dataset.loc[ dataset['PeakCallsInOut'] ==0.0, 'PeakCallsInOut'] = 0
    dataset.loc[(dataset['PeakCallsInOut'] > 0.0) & (dataset['PeakCallsInOut'] <= 320.0), 'PeakCallsInOut'] = 1
    dataset.loc[(dataset['PeakCallsInOut'] > 320.0) & (dataset['PeakCallsInOut'] <= 640.0), 'PeakCallsInOut'] = 2
    dataset.loc[(dataset['PeakCallsInOut'] > 640.0) & (dataset['PeakCallsInOut'] <= 960.0), 'PeakCallsInOut'] = 3
    dataset.loc[(dataset['PeakCallsInOut'] > 960.0) & (dataset['PeakCallsInOut'] <= 1280.0), 'PeakCallsInOut'] = 4
    dataset.loc[(dataset['PeakCallsInOut'] > 1280.0) & (dataset['PeakCallsInOut'] <= 1600.0), 'PeakCallsInOut'] = 5
    dataset.loc[(dataset['PeakCallsInOut'] > 1600.0) & (dataset['PeakCallsInOut'] <= 2090.7), 'PeakCallsInOut'] = 6
    dataset['PeakCallsInOut'] = dataset['PeakCallsInOut'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[ dataset['OffPeakCallsInOut'] ==0.0, 'OffPeakCallsInOut'] = 0
    dataset.loc[(dataset['OffPeakCallsInOut'] > 0.0) & (dataset['OffPeakCallsInOut'] <= 240.0), 'OffPeakCallsInOut'] = 1
    dataset.loc[(dataset['OffPeakCallsInOut'] > 240.0) & (dataset['OffPeakCallsInOut'] <= 480.0), 'OffPeakCallsInOut'] = 2
    dataset.loc[(dataset['OffPeakCallsInOut'] > 480.0) & (dataset['OffPeakCallsInOut'] <= 720.0), 'OffPeakCallsInOut'] = 3
    dataset.loc[(dataset['OffPeakCallsInOut'] > 720.0) & (dataset['OffPeakCallsInOut'] <= 960.0), 'OffPeakCallsInOut'] = 4
    dataset.loc[(dataset['OffPeakCallsInOut'] > 960.0) & (dataset['OffPeakCallsInOut'] <= 1200.0), 'OffPeakCallsInOut'] = 5
    dataset.loc[(dataset['OffPeakCallsInOut'] > 1200.0) & (dataset['OffPeakCallsInOut'] <= 1474.7), 'OffPeakCallsInOut'] = 6
    dataset['OffPeakCallsInOut'] = dataset['OffPeakCallsInOut'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['CurrentEquipmentDays'] >= -5.0) & (dataset['CurrentEquipmentDays'] <= 300.0), 'CurrentEquipmentDays'] = 1
    dataset.loc[(dataset['CurrentEquipmentDays'] > 300.0) & (dataset['CurrentEquipmentDays'] <= 600.0), 'CurrentEquipmentDays'] = 2
    dataset.loc[(dataset['CurrentEquipmentDays'] > 600.0) & (dataset['CurrentEquipmentDays'] <= 900.0), 'CurrentEquipmentDays'] = 3
    dataset.loc[(dataset['CurrentEquipmentDays'] > 900.0) & (dataset['CurrentEquipmentDays'] <= 1200.0), 'CurrentEquipmentDays'] = 4
    dataset.loc[(dataset['CurrentEquipmentDays'] > 1200.0) & (dataset['CurrentEquipmentDays'] <= 1500.0), 'CurrentEquipmentDays'] = 5
    dataset.loc[(dataset['CurrentEquipmentDays'] > 1500.0) & (dataset['CurrentEquipmentDays'] <= 1812.0), 'CurrentEquipmentDays'] = 6
    dataset['CurrentEquipmentDays'] = dataset['CurrentEquipmentDays'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['MonthlyMinutes'] >= 0) & (dataset['MonthlyMinutes'] <= 500), 'MonthlyMinutes'] = 1
    dataset.loc[(dataset['MonthlyMinutes'] > 500) & (dataset['MonthlyMinutes'] <= 1500), 'MonthlyMinutes'] = 2
    dataset.loc[(dataset['MonthlyMinutes'] > 1500) & (dataset['MonthlyMinutes'] <= 2500), 'MonthlyMinutes'] = 3
    dataset.loc[(dataset['MonthlyMinutes'] > 2500) & (dataset['MonthlyMinutes'] <= 4500), 'MonthlyMinutes'] = 4
    dataset.loc[(dataset['MonthlyMinutes'] > 4500) & (dataset['MonthlyMinutes'] <= 5700), 'MonthlyMinutes'] = 5
    dataset.loc[(dataset['MonthlyMinutes'] > 5700) & (dataset['MonthlyMinutes'] <= 7359), 'MonthlyMinutes'] = 6
    dataset['MonthlyMinutes'] = dataset['MonthlyMinutes'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['ReceivedCalls'] >= 0.0) & (dataset['ReceivedCalls'] <= 200.0), 'ReceivedCalls'] = 1
    dataset.loc[(dataset['ReceivedCalls'] > 200.0) & (dataset['ReceivedCalls'] <= 400.0), 'ReceivedCalls'] = 2
    dataset.loc[(dataset['ReceivedCalls'] > 400.0) & (dataset['ReceivedCalls'] <= 800.0), 'ReceivedCalls'] = 3
    dataset.loc[(dataset['ReceivedCalls'] > 800.0) & (dataset['ReceivedCalls'] <= 1200.0), 'ReceivedCalls'] = 4
    dataset.loc[(dataset['ReceivedCalls'] > 1200.0) & (dataset['ReceivedCalls'] <= 1600.0), 'ReceivedCalls'] = 5
    dataset.loc[(dataset['ReceivedCalls'] > 1600.0) & (dataset['ReceivedCalls'] <= 2692.4), 'ReceivedCalls'] = 6
    dataset['ReceivedCalls'] = dataset['ReceivedCalls'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['PercChangeMinutes'] >= -3875.0) & (dataset['PercChangeMinutes'] <= -2310.0), 'PercChangeMinutes'] = 1
    dataset.loc[(dataset['PercChangeMinutes'] > -2310.0) & (dataset['PercChangeMinutes'] <= -1400.0), 'PercChangeMinutes'] = 2
    dataset.loc[(dataset['PercChangeMinutes'] > -1400.0) & (dataset['PercChangeMinutes'] <= -300.0), 'PercChangeMinutes'] = 3
    dataset.loc[(dataset['PercChangeMinutes'] > -300.0) & (dataset['PercChangeMinutes'] <= 100), 'PercChangeMinutes'] = 4
    dataset.loc[(dataset['PercChangeMinutes'] > 100 ) & (dataset['PercChangeMinutes'] <= 256.91), 'PercChangeMinutes'] = 5
    dataset.loc[(dataset['PercChangeMinutes'] > 256.91) & (dataset['PercChangeMinutes'] <= 1024.0), 'PercChangeMinutes'] = 6
    dataset.loc[(dataset['PercChangeMinutes'] > 1024.0) & (dataset['PercChangeMinutes'] <= 2354.0), 'PercChangeMinutes'] = 7
    dataset.loc[(dataset['PercChangeMinutes'] > 2354.0) & (dataset['PercChangeMinutes'] <= 3912.0), 'PercChangeMinutes'] = 8
    dataset.loc[(dataset['PercChangeMinutes'] > 3912.0) & (dataset['PercChangeMinutes'] <= 5192.0), 'PercChangeMinutes'] = 9
    dataset['PercChangeMinutes'] = dataset['PercChangeMinutes'].astype('int64')

# %%
train_df['UnansweredCalls']=train_df['UnansweredCalls'].astype('int64')
train_df['OutboundCalls'] = train_df['OutboundCalls'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['OverageMinutes'] <= 0) , 'OverageMinutes'] = 0
    dataset.loc[(dataset['OverageMinutes'] > 0) & (dataset['OverageMinutes'] <= 50), 'OverageMinutes'] = 1
    dataset.loc[(dataset['OverageMinutes'] > 50) & (dataset['OverageMinutes'] <= 100), 'OverageMinutes'] = 2
    dataset.loc[(dataset['OverageMinutes'] > 100) & (dataset['OverageMinutes'] <= 500), 'OverageMinutes'] = 3
    dataset.loc[(dataset['OverageMinutes'] > 500) , 'OverageMinutes'] = 4
    dataset['OverageMinutes'] = dataset['OverageMinutes'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['PercChangeRevenues'] <=-200), 'PercChangeRevenues'] = 1
    dataset.loc[(dataset['PercChangeRevenues'] > -200) & (dataset['PercChangeRevenues'] <= -50), 'PercChangeRevenues'] = 2
    dataset.loc[(dataset['PercChangeRevenues'] > -50) & (dataset['PercChangeRevenues'] <=-10), 'PercChangeRevenues'] = 3
    dataset.loc[(dataset['PercChangeRevenues'] > -10) & (dataset['PercChangeRevenues'] < 0), 'PercChangeRevenues'] = 4
    dataset.loc[(dataset['PercChangeRevenues'] == 0) , 'PercChangeRevenues'] = 0
    dataset.loc[(dataset['PercChangeRevenues'] > 0) & (dataset['PercChangeRevenues'] <= 50), 'PercChangeRevenues'] = 5
    dataset.loc[(dataset['PercChangeRevenues'] > 50) & (dataset['PercChangeRevenues'] <= 200), 'PercChangeRevenues'] = 6
    dataset.loc[(dataset['PercChangeRevenues'] > 200), 'PercChangeRevenues'] = 7
    dataset['PercChangeRevenues'] = dataset['PercChangeRevenues'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['OutboundCalls'] == 0) , 'OutboundCalls'] = 0
    dataset.loc[(dataset['OutboundCalls'] > 0) & (dataset['OutboundCalls'] <= 100), 'OutboundCalls'] = 1
    dataset.loc[(dataset['OutboundCalls'] > 100) & (dataset['OutboundCalls'] <= 200), 'OutboundCalls'] = 2
    dataset.loc[(dataset['OutboundCalls'] > 200) & (dataset['OutboundCalls'] <= 300), 'OutboundCalls'] = 3
    dataset.loc[(dataset['OutboundCalls'] > 300) & (dataset['OutboundCalls'] <= 400), 'OutboundCalls'] = 4
    dataset.loc[(dataset['OutboundCalls'] > 400) & (dataset['OutboundCalls'] <= 500), 'OutboundCalls'] = 5
    dataset.loc[(dataset['OutboundCalls'] > 500) & (dataset['OutboundCalls'] <= 644), 'OutboundCalls'] = 6

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['UnansweredCalls'] == 0) , 'UnansweredCalls'] = 0
    dataset.loc[(dataset['UnansweredCalls'] > 0) & (dataset['UnansweredCalls'] <= 140), 'UnansweredCalls'] = 1
    dataset.loc[(dataset['UnansweredCalls'] > 140) & (dataset['UnansweredCalls'] <= 280), 'UnansweredCalls'] = 2
    dataset.loc[(dataset['UnansweredCalls'] > 280) & (dataset['UnansweredCalls'] <= 420), 'UnansweredCalls'] = 3
    dataset.loc[(dataset['UnansweredCalls'] > 420) & (dataset['UnansweredCalls'] <= 560), 'UnansweredCalls'] = 4
    dataset.loc[(dataset['UnansweredCalls'] > 560) & (dataset['UnansweredCalls'] <= 700), 'UnansweredCalls'] = 5
    dataset.loc[(dataset['UnansweredCalls'] > 700) & (dataset['UnansweredCalls'] <= 848), 'UnansweredCalls'] = 6

# %%
dropping=[ ['RoamingCalls'],['DroppedCalls'],
['BlockedCalls'],['CustomerCareCalls'],
['ThreewayCalls'],['InboundCalls'],
['DroppedBlockedCalls'],['CallForwardingCalls'],
['CallWaitingCalls']]
for i in range(0,len(dropping)) :
    train_df=train_df.drop(columns=dropping[i])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   MonthlyRevenue             51047 non-null  int64
#  2   MonthlyMinutes             51047 non-null  int64
#  3   TotalRecurringCharge       51047 non-null  int64
#  4   DirectorAssistedCalls      51047 non-null  int64
#  5   OverageMinutes             51047 non-null  int64
#  6   PercChangeMinutes          51047 non-null  int64
#  7   PercChangeRevenues         51047 non-null  int64
#  8   UnansweredCalls            51047 non-null  int64
#  9   ReceivedCalls              51047 non-null  int64
#  10  OutboundCalls              51047 non-null  int64
#  11  PeakCallsInOut             51047 non-null  int64
#  12  OffPeakCallsInOut          51047 non-null  int64
# ...

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['MonthlyRevenue'] >=-6 ) & (dataset['MonthlyRevenue'] <= 25), 'MonthlyRevenue'] = 1
    dataset.loc[(dataset['MonthlyRevenue'] > 25) & (dataset['MonthlyRevenue'] <= 50), 'MonthlyRevenue'] = 2
    dataset.loc[(dataset['MonthlyRevenue'] > 50) & (dataset['MonthlyRevenue'] <= 75), 'MonthlyRevenue'] = 3
    dataset.loc[(dataset['MonthlyRevenue'] > 75) & (dataset['MonthlyRevenue'] <= 100), 'MonthlyRevenue'] = 4
    dataset.loc[(dataset['MonthlyRevenue'] > 100) , 'MonthlyRevenue'] = 5
    dataset['MonthlyRevenue']=dataset['MonthlyRevenue'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['TotalRecurringCharge'] >=-11 ) & (dataset['TotalRecurringCharge'] <= 30), 'TotalRecurringCharge'] = 1
    dataset.loc[(dataset['TotalRecurringCharge'] > 30) & (dataset['TotalRecurringCharge'] <= 100), 'TotalRecurringCharge'] = 2
    dataset.loc[(dataset['TotalRecurringCharge'] > 100) & (dataset['TotalRecurringCharge'] <= 220), 'TotalRecurringCharge'] = 3
    dataset.loc[(dataset['TotalRecurringCharge'] > 220) & (dataset['TotalRecurringCharge'] <= 400), 'TotalRecurringCharge'] = 4
    dataset['TotalRecurringCharge']=dataset['TotalRecurringCharge'].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['DirectorAssistedCalls'] == 0 ), 'DirectorAssistedCalls'] = 0
    dataset.loc[(dataset['DirectorAssistedCalls'] > 0 ) & (dataset['DirectorAssistedCalls'] <= 10), 'DirectorAssistedCalls'] = 1
    dataset.loc[(dataset['DirectorAssistedCalls'] > 10) & (dataset['DirectorAssistedCalls'] <= 20), 'DirectorAssistedCalls'] = 2
    dataset.loc[(dataset['DirectorAssistedCalls'] > 20) & (dataset['DirectorAssistedCalls'] <= 30), 'DirectorAssistedCalls'] = 3
    dataset.loc[(dataset['DirectorAssistedCalls'] > 30) & (dataset['DirectorAssistedCalls'] <= 40), 'DirectorAssistedCalls'] = 4
    dataset.loc[(dataset['DirectorAssistedCalls'] > 40) , 'DirectorAssistedCalls'] = 5
    dataset['DirectorAssistedCalls']=dataset['DirectorAssistedCalls'].astype('int64')

# %%
variable = ['AgeHH1','AgeHH2']
for i in range(0,len(variable)) :
    data = [train_df]
    for dataset in data:
        dataset.loc[(dataset[variable[i]] == 0 ), variable[i]] = 0
        dataset.loc[(dataset[variable[i]] > 0 ) & (dataset[variable[i]] <= 18),variable[i]] = 1
        dataset.loc[(dataset[variable[i]] > 18) & (dataset[variable[i]] <= 30),variable[i]] = 2
        dataset.loc[(dataset[variable[i]] > 30) & (dataset[variable[i]] <= 48),variable[i]] = 3
        dataset.loc[(dataset[variable[i]] > 48) & (dataset[variable[i]] <= 65),variable[i]] = 4
        dataset.loc[(dataset[variable[i]] > 65) ,variable[i]] = 5
        dataset[variable[i]]=dataset[variable[i]].astype('int64')

# %%
data = [train_df]
for dataset in data:
    dataset.loc[(dataset['MonthsInService'] >=6 ) & (dataset['MonthsInService'] <= 17), 'MonthsInService'] = 1
    dataset.loc[(dataset['MonthsInService'] > 17) & (dataset['MonthsInService'] <= 28), 'MonthsInService'] = 2
    dataset.loc[(dataset['MonthsInService'] > 28) & (dataset['MonthsInService'] <= 39), 'MonthsInService'] = 3
    dataset.loc[(dataset['MonthsInService'] > 39) & (dataset['MonthsInService'] <= 50), 'MonthsInService'] = 4
    dataset.loc[(dataset['MonthsInService'] > 50) & (dataset['MonthsInService'] <= 61), 'MonthsInService'] = 5
    dataset['MonthsInService']=dataset['MonthsInService'].astype('int64')

# %%
train_df.head()
# Out:
#    CustomerID  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002               1               1                     1
# 1     3000010               1               1                     1
# 2     3000014               2               1                     2
# 3     3000022               4               2                     2
# 4     3000026               1               1                     1
#
#    DirectorAssistedCalls  OverageMinutes  PercChangeMinutes  \
# 0                      0               0                  4
# 1                      0               0                  4
# 2                      0               0                  4
# 3                      1               0                  5
# 4                      0               0                  4
#
#    PercChangeRevenues  UnansweredCalls  ReceivedCalls  ...  BuysViaMailOrder  \
# 0                   5                1              1  ...                 0
# ...

# %%
train_df['ServiceArea']=train_df['ServiceArea'].replace(list(train_df.ServiceArea.unique()),np.arange(train_df.ServiceArea.nunique()))
train_df['ServiceArea']=train_df['ServiceArea'].astype('int64')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   MonthlyRevenue             51047 non-null  int64
#  2   MonthlyMinutes             51047 non-null  int64
#  3   TotalRecurringCharge       51047 non-null  int64
#  4   DirectorAssistedCalls      51047 non-null  int64
#  5   OverageMinutes             51047 non-null  int64
#  6   PercChangeMinutes          51047 non-null  int64
#  7   PercChangeRevenues         51047 non-null  int64
#  8   UnansweredCalls            51047 non-null  int64
#  9   ReceivedCalls              51047 non-null  int64
#  10  OutboundCalls              51047 non-null  int64
#  11  PeakCallsInOut             51047 non-null  int64
#  12  OffPeakCallsInOut          51047 non-null  int64
# ...

# %%
Customer = train_df.CustomerID.copy()

# %%
train_df=train_df.drop('CustomerID',axis=1)

# %%
train_df.head()
# Out:
#    MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0               1               1                     1
# 1               1               1                     1
# 2               2               1                     2
# 3               4               2                     2
# 4               1               1                     1
#
#    DirectorAssistedCalls  OverageMinutes  PercChangeMinutes  \
# 0                      0               0                  4
# 1                      0               0                  4
# 2                      0               0                  4
# 3                      1               0                  5
# 4                      0               0                  4
#
#    PercChangeRevenues  UnansweredCalls  ReceivedCalls  OutboundCalls  ...  \
# 0                   5                1              1              0  ...
# 1                   0                1              1              0  ...
# ...

# %%
train_df['Churn'] = df['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
train_df.Churn.value_counts().plot(kind='bar')

# %%
import itertools
import pickle
from mlxtend.plotting import plot_decision_regions
from mlxtend.classifier import StackingClassifier 


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (RandomForestClassifier, ExtraTreesClassifier, VotingClassifier, 
                              AdaBoostClassifier, BaggingClassifier,GradientBoostingClassifier)

from sklearn.svm import SVC,LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, make_scorer,precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate

# %%
X=train_df.drop('Churn',axis=1)
y=train_df.Churn
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=57)

# %%
logreg = LogisticRegression(solver="lbfgs")
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
acc_log_train = round(logreg.score(X_train, y_train) * 100, 2)
acc_log_test = round(logreg.score(X_test, y_test) * 100, 2)
# Out:
# C:\Users\rtkik\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train) 
y_pred = knn.predict(X_test)  
acc_knn_train = round(knn.score(X_train, y_train) * 100, 2)
acc_knn_test = round(knn.score(X_test, y_test) * 100, 2)

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)  
y_pred = gaussian.predict(X_test)  
acc_gaussian_train = round(gaussian.score(X_train, y_train) * 100, 2)
acc_gaussian_test = round(gaussian.score(X_test, y_test) * 100, 2)

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, y_train)
y_pred = linear_svc.predict(X_test)
acc_linear_svc_train = round(linear_svc.score(X_train, y_train) * 100, 2)
acc_linear_svc_test = round(linear_svc.score(X_test, y_test) * 100, 2)
# Out:
# C:\Users\rtkik\anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
svc =SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
acc_svc_train = round(svc.score(X_train, y_train) * 100, 2)
acc_svc_test = round(svc.score(X_test, y_test) * 100, 2)

# %%
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(X_train, y_train) 
y_pred = decision_tree.predict(X_test) 
acc_decision_tree_train = round(decision_tree.score(X_train, y_train) * 100, 2)
acc_decision_tree_test = round(decision_tree.score(X_test, y_test) * 100, 2)

# %%
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
acc_random_forest_train = round(random_forest.score(X_train, y_train) * 100, 2)
acc_random_forest_test = round(random_forest.score(X_test, y_test) * 100, 2)

# %%
extra_trees = ExtraTreesClassifier(n_estimators=100)
extra_trees.fit(X_train, y_train)
y_pred = extra_trees.predict(X_test)
acc_extra_trees_train = round(extra_trees.score(X_train, y_train) * 100, 2)
acc_extra_trees_test = round(extra_trees.score(X_test, y_test) * 100, 2)

# %%
ada_boost= AdaBoostClassifier(n_estimators=100)
ada_boost.fit(X_train, y_train)
y_pred = ada_boost.predict(X_test)
acc_ada_boost_train = round(ada_boost.score(X_train, y_train) * 100, 2)
acc_ada_boost_test = round(ada_boost.score(X_test, y_test) * 100, 2)

# %%
gradient_boost = GradientBoostingClassifier(n_estimators=100)
gradient_boost.fit(X_train, y_train)
y_pred = gradient_boost.predict(X_test)
acc_gradient_boost_train = round(gradient_boost.score(X_train, y_train) * 100, 2)
acc_gradient_boost_test = round(gradient_boost.score(X_test, y_test) * 100, 2)

# %%
bagging = BaggingClassifier(base_estimator=decision_tree, n_estimators=100)
bagging.fit(X_train,y_train)
y_pred = bagging.predict(X_test)
acc_bagging_train = round(bagging.score(X_train, y_train) * 100, 2)
acc_bagging_test = round(bagging.score(X_test, y_test) * 100, 2)

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN','Naive Bayes',
              'Linear SVC','SVC','Decision Tree',   
              'Random Forest',  'Extra Trees','Ada Boost', 
              'Gradient Boost','Bagging' ],
    'TrainScore': [acc_log_train,acc_knn_train,acc_gaussian_train,acc_linear_svc_train,
                  acc_svc_train,acc_decision_tree_train,acc_random_forest_train,
                  acc_extra_trees_train,acc_ada_boost_train,acc_gradient_boost_train,
                  acc_bagging_train],
    'TestScore' : [acc_log_test,acc_knn_test,acc_gaussian_test,acc_linear_svc_test,
                  acc_svc_test,acc_decision_tree_test,acc_random_forest_test,
                  acc_extra_trees_test,acc_ada_boost_test,acc_gradient_boost_test,
                  acc_bagging_test]})
result_df = results.sort_values(by='TrainScore', ascending=False)
result_df = result_df.set_index('Model')
result_df.head(11)
# Out:
#                      TrainScore  TestScore
# Model
# Decision Tree             99.93      60.41
# Random Forest             99.93      70.94
# Extra Trees               99.93      70.58
# Bagging                   99.93      70.21
# KNN                       76.10      66.84
# Gradient Boost            71.74      71.43
# Ada Boost                 71.30      71.36
# SVC                       71.19      71.17
# Logistic Regression       71.14      71.57
# Naive Bayes               67.49      67.20
# Linear SVC                43.22      42.80

# %%
result_df['Average']=round((result_df['TrainScore']+result_df['TestScore'])/2,2)

# %%
result_df=result_df.sort_values(by='Average',ascending=False)

# %%
result_df
# Out:
#                      TrainScore  TestScore  Average
# Model
# Random Forest             99.93      70.94    85.44
# Extra Trees               99.93      70.58    85.26
# Bagging                   99.93      70.21    85.07
# Decision Tree             99.93      60.41    80.17
# Gradient Boost            71.74      71.43    71.59
# KNN                       76.10      66.84    71.47
# Logistic Regression       71.14      71.57    71.35
# Ada Boost                 71.30      71.36    71.33
# SVC                       71.19      71.17    71.18
# Naive Bayes               67.49      67.20    67.34
# Linear SVC                43.22      42.80    43.01

# %%
from sklearn.model_selection import cross_val_score

metric=['accuracy','recall','precision']
for i in range (0,len(metric)) :
    scores = cross_val_score(random_forest, X_train, y_train, cv=10, scoring = metric[i])
    print(metric[i],"Scores:", scores)
    print(metric[i],"Mean:", scores.mean())
    print(metric[i],"Standard Deviation:", scores.std())
    print('--------------------------')
# Out:
# accuracy Scores: [0.70739471 0.70910872 0.70763957 0.70225269 0.70714985 0.70372184
#  0.70788443 0.70585354 0.69997551 0.71050698]
# accuracy Mean: 0.706148783937988
# accuracy Standard Deviation: 0.0030791317475534177
# --------------------------
# recall Scores: [0.06881903 0.06796941 0.06966865 0.06796941 0.08581138 0.0722175
#  0.07731521 0.07397959 0.08333333 0.07908163]
# recall Mean: 0.07461651610516765
# recall Standard Deviation: 0.006173728937754617
# --------------------------
# precision Scores: [0.46268657 0.42307692 0.44148936 0.40776699 0.48019802 0.44444444
#  0.48543689 0.44270833 0.39495798 0.40526316]
# precision Mean: 0.4388028674106147
# precision Standard Deviation: 0.02961559792471805
# --------------------------

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(random_forest.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
# Out:
#                            importance
# feature
# ServiceArea                     0.117
# IncomeGroup                     0.058
# CreditRating                    0.052
# PrizmCode                       0.044
# MonthlyRevenue                  0.042
# CurrentEquipmentDays            0.040
# OverageMinutes                  0.036
# AgeHH1                          0.035
# AgeHH2                          0.033
# UniqueSubs                      0.028
# Occupation                      0.027
# MonthsInService                 0.027
# HandsetPrice                    0.025
# MaritalStatus                   0.025
# PercChangeRevenues              0.024
# Handsets                        0.024
# PercChangeMinutes               0.023
# MonthlyMinutes                  0.020
# ActiveSubs                      0.020
# NewCellphoneUser                0.019
# DirectorAssistedCalls           0.019
# HandsetModels                   0.018
# TotalRecurringCharge            0.017
# ...

# %%
importances.head(20).plot.bar()

# %%
importances_value
# Out:
# ['ServiceArea',
#  'IncomeGroup',
#  'CreditRating',
#  'PrizmCode',
#  'MonthlyRevenue',
#  'CurrentEquipmentDays',
#  'OverageMinutes',
#  'AgeHH1',
#  'AgeHH2',
#  'UniqueSubs',
#  'Occupation',
#  'MonthsInService',
#  'HandsetPrice',
#  'MaritalStatus',
#  'PercChangeRevenues',
#  'Handsets',
#  'PercChangeMinutes',
#  'MonthlyMinutes',
#  'ActiveSubs',
#  'NewCellphoneUser',
#  'Churn']

# %%
importances_value=list(importances.head(20).index)
importances_value.append('Churn')

# %%
train_df=train_df.loc[:,importances_value]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ServiceArea           51047 non-null  int64
#  1   IncomeGroup           51047 non-null  int64
#  2   CreditRating          51047 non-null  int64
#  3   PrizmCode             51047 non-null  int64
#  4   MonthlyRevenue        51047 non-null  int64
#  5   CurrentEquipmentDays  51047 non-null  int64
#  6   OverageMinutes        51047 non-null  int64
#  7   AgeHH1                51047 non-null  int64
#  8   AgeHH2                51047 non-null  int64
#  9   UniqueSubs            51047 non-null  int64
#  10  Occupation            51047 non-null  int64
#  11  MonthsInService       51047 non-null  int64
#  12  HandsetPrice          51047 non-null  int64
#  13  MaritalStatus         51047 non-null  int64
#  14  PercChangeRevenues    51047 non-null  int64
# ...

# %%
train_df.to_csv('C:/Users/rtkik/OneDrive/Desktop/Data Science/Telecom Churn/train_df.csv',index=False)

# %%
X=train_df.drop('Churn',axis=1)
y=train_df.Churn
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=57)

# %%
from sklearn.model_selection import cross_val_score

metric=['accuracy','recall','precision']
for i in range (0,len(metric)) :
    scores = cross_val_score(random_forest, X_train, y_train, cv=10, scoring = metric[i])
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard Deviation:", scores.std())
    print('--------------------------')
# Out:
# Scores: [0.69417238 0.68952008 0.7010284  0.69686582 0.70249755 0.69539667
#  0.69857982 0.698506   0.69801616 0.70046534]
# Mean: 0.6975048233964051
# Standard Deviation: 0.003581076030720779
# --------------------------
# Scores: [0.08836024 0.08751062 0.08411215 0.07646559 0.10195412 0.0960068
#  0.10705183 0.08418367 0.09183673 0.10119048]
# Mean: 0.09186722267496633
# Standard Deviation: 0.00907769276477808
# --------------------------
# Scores: [0.36428571 0.36       0.41198502 0.38339921 0.42804428 0.40559441
#  0.42599278 0.38129496 0.41240876 0.4       ]
# Mean: 0.397300513147194
# Standard Deviation: 0.02284540248062968
# --------------------------

# %%
random_forest = RandomForestClassifier(n_estimators=100, oob_score = True)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
random_forest.score(X_train, y_train)
acc_random_forest = round(random_forest.score(X_train, y_train) * 100, 2)
print(round(acc_random_forest,2,), "%")
print("Precision: {:6.4f},   Recall: {:6.4f}".format(precision_score(y_test, y_pred), 
                                                     recall_score(y_test, y_pred)))
# Out:
# 99.67 %
# Precision: 0.3859,   Recall: 0.0931

# %%
y_predict = (random_forest.predict_proba(X_test)[:,1] > 0.06)
print("Threshold of 0.06:")
print("Precision: {:6.4f},   Recall: {:6.4f}".format(precision_score(y_test, y_predict), 
                                                     recall_score(y_test, y_predict)))
# Out:
# Threshold of 0.06:
# Precision: 0.2932,   Recall: 0.9881

# %%
from sklearn.metrics import confusion_matrix
def make_confusion_matrix(model, threshold,figsize=(10,7)):
    # Predict class 1 if probability of being in class 1 is greater than threshold
    # (model.predict(X_test) does this automatically with a threshold of 0.5)
    y_predict = (model.predict_proba(X_test)[:, 1] >= threshold)
    churn_confusion = confusion_matrix(y_test, y_predict)
    plt.figure(figsize=figsize)
    sns.heatmap(churn_confusion, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
           xticklabels=['NotChurn', 'Churn'],
           yticklabels=['NotChurn', 'Churn']);
    plt.xlabel('prediction')
    plt.ylabel('actual')

# %%
make_confusion_matrix(random_forest,0.5)

# %%
make_confusion_matrix(random_forest,0.3)

# %%
print('After OverSampling, the shape of train_X: {}'.format(X_train.shape)) 
print('After OverSampling, the shape of train_y: {} \n'.format(y_train.shape))

print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1))) 
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0))) 
  
# import SMOTE module from imblearn library 
# pip install imblearn (if you don't have imblearn in your system) 
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2) 
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel()) 
  
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape)) 
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape)) 
  
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# After OverSampling, the shape of train_X: (40837, 20)
# After OverSampling, the shape of train_y: (40837,)
#
# Before OverSampling, counts of label '1': 11767
# Before OverSampling, counts of label '0': 29070
#
# After OverSampling, the shape of train_X: (58140, 20)
# After OverSampling, the shape of train_y: (58140,)
#
# After OverSampling, counts of label '1': 29070
# After OverSampling, counts of label '0': 29070

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train_res, y_train_res)
y_pred = random_forest.predict(X_test)
acc_random_forest = round(random_forest.score(X_train_res, y_train_res) * 100, 2)

# %%
print("Precision: {:6.4f},   Recall: {:6.4f}".format(precision_score(y_test, y_pred), 
                                                     recall_score(y_test, y_pred)))
# Out:
# Precision: 0.3439,   Recall: 0.3162

# %%
y_predict = (random_forest.predict_proba(X_test)[:,1] > 0.06)
print("Threshold of 0.06:")
print("Precision: {:6.4f},   Recall: {:6.4f}".format(precision_score(y_test, y_predict), 
                                                     recall_score(y_test, y_predict)))
# Out:
# Threshold of 0.06:
# Precision: 0.2894,   Recall: 0.9980

# %%
make_confusion_matrix(random_forest,0.5)

# %%
make_confusion_matrix(random_forest,0.3)

# %%
from ipywidgets import interactive, FloatSlider

interactive(lambda threshold: make_confusion_matrix(random_forest, threshold), threshold=(0.0,1.0,0.02))
# Out:
# interactive(children=(FloatSlider(value=0.5, description='threshold', max=1.0, step=0.02), Output()), _dom_cla…

# %%
from sklearn import model_selection
kfold = model_selection.KFold(n_splits=10)
estimators = []
estimators.append(('logistic', logreg))
estimators.append(('cart',decision_tree ))
estimators.append(('svm', svc))
# create the ensemble model
ensemble = VotingClassifier(estimators)
results = model_selection.cross_val_score(ensemble, X_train, y_train, cv=kfold)
print(results.mean())
# Out:
# C:\Users\rtkik\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\rtkik\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
param_grid = { "criterion" : ["gini", "entropy"], "min_samples_leaf" : [1, 5, 10, 25, 50, 70], "min_samples_split" : [2, 4, 10, 12, 16, 18, 25, 35], "n_estimators": [100, 400, 700, 1000, 1500]}
from sklearn.model_selection import GridSearchCV, cross_val_score
random_forest = RandomForestClassifier(n_estimators=100, max_features='auto', oob_score=True, random_state=1, n_jobs=-1)
clf = GridSearchCV(estimator=random_forest, param_grid=param_grid, n_jobs=-1)
clf.fit(X_train_res,y_train_res)
clf.best_params_
# Out:
# C:\Users\rtkik\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
random_forest = RandomForestClassifier(criterion = "gini", 
                                       min_samples_leaf = 1, 
                                       min_samples_split = 10,   
                                       n_estimators=100, 
                                       max_features='auto', 
                                       oob_score=True, 
                                       random_state=1, 
                                       n_jobs=-1)

random_forest.fit(X_train_res, y_train_res)
y_pred = random_forest.predict(X_test)
print("oob score:", round(random_forest.oob_score_, 4)*100, "%")
# Out:
# oob score: 71.93 %

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
predictions = cross_val_predict(random_forest, X_train_res, y_train_res, cv=3)
confusion_matrix(y_train_res, predictions)
# Out:
# array([[20966,  8104],
#        [ 9922, 19148]], dtype=int64)

# %%
print("Precision:", precision_score(y_train_res, predictions))
print("Recall:",recall_score(y_train_res, predictions))
# Out:
# Precision: 0.7026273301042125
# Recall: 0.6586859305125559

# %%
f1_score(y_train_res, predictions)
# Out:
# 0.6799474450481161

# %%
y_scores = random_forest.predict_proba(X_train_res)
y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(y_train_res, y_scores)
def plot_precision_and_recall(precision, recall, threshold):
    plt.plot(threshold, precision[:-1], "r-", label="precision", linewidth=5)
    plt.plot(threshold, recall[:-1], "b", label="recall", linewidth=5)
    plt.xlabel("threshold", fontsize=19)
    plt.legend(loc="upper right", fontsize=19)
    plt.ylim([0, 1])

plt.figure(figsize=(14, 7))
plot_precision_and_recall(precision, recall, threshold)
plt.show()

# %%
def plot_precision_vs_recall(precision, recall):
    plt.plot(recall, precision, "g--", linewidth=2.5)
    plt.ylabel("recall", fontsize=19)
    plt.xlabel("precision", fontsize=19)
    plt.axis([0, 1.5, 0, 1.5])

plt.figure(figsize=(14, 7))
plot_precision_vs_recall(precision, recall)
plt.show()

# %%
from sklearn.metrics import roc_curve
# compute true positive rate and false positive rate
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train_res, y_scores)
# plotting them against each other
def plot_roc_curve(false_positive_rate, true_positive_rate, label=None):
    plt.plot(false_positive_rate, true_positive_rate, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'r', linewidth=4)
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate (FPR)', fontsize=16)
    plt.ylabel('True Positive Rate (TPR)', fontsize=16)

plt.figure(figsize=(14, 7))
plot_roc_curve(false_positive_rate, true_positive_rate)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
r_a_score = roc_auc_score(y_train_res, y_scores)
print("ROC-AUC-Score:", r_a_score)
# Out:
# ROC-AUC-Score: 0.982151948329649
